# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Data Cleaning

# %%
df = pd.read_csv("data/vehicles_messy.csv", low_memory=False)

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# 0  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#    phevCity  phevHwy  phevComb
# 0         0        0         0
# 1         0        0         0
# 2         0        0         0
# 3         0        0         0
# 4         0        0         0
#
# [5 rows x 83 columns]

# %%
#how many columns
len(df.columns)
# Out:
# 83

# %%
#how many values
df.size
# Out:
# 3140969

# %%
#no of rows
len(df)
# Out:
# 37843

# %%
#no of rows and no of columns
df.shape
# Out:
# (37843, 83)

# %% [markdown]
# ## Data Cleaning Steps
# 1. Handle missing values
# 2. Look at information contained in columns (variance)
# 3. Detect outliers
# 4. Convert types
# 5. String Operations
# 6. Treat duplicate

# %% [markdown]
# ## 1. Handle Missing Values

# %%
df.isna()
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0          False       False      False      False   False    False    False
# 1          False       False      False      False   False    False    False
# 2          False       False      False      False   False    False    False
# 3          False       False      False      False   False    False    False
# 4          False       False      False      False   False    False    False
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838      False       False      False      False   False    False    False
# 37839      False       False      False      False   False    False    False
# 37840      False       False      False      False   False    False    False
# 37841      False       False      False      False   False    False    False
# 37842      False       False      False      False   False    False    False
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0         False   False  False  ...     True      True       False       True
# 1         False   False  False  ...     True      True       False       True
# 2         False   False  False  ...     True      True       False       True
# 3         False   False  False  ...     True      True       False       True
# 4         False   False  False  ...     True      True       False       True
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 37838     False   False  False  ...     True      True       False       True
# 37839     False   False  False  ...     True      True       False       True
# 37840     False   False  False  ...     True      True       False       True
# 37841     False   False  False  ...     True      True       False       True
# 37842     False   False  False  ...     True      True       False       True
#
#        createdOn  modifiedOn  startStop  phevCity  phevHwy  phevComb
# 0          False       False       True     False    False     False
# 1          False       False       True     False    False     False
# 2          False       False       True     False    False     False
# 3          False       False       True     False    False     False
# 4          False       False       True     False    False     False
# ...          ...         ...        ...       ...      ...       ...
# 37838      False       False       True     False    False     False
# 37839      False       False       True     False    False     False
# 37840      False       False       True     False    False     False
# 37841      False       False       True     False    False     False
# 37842      False       False       True     False    False     False
#
# [37843 rows x 83 columns]

# %%
df.isna().sum()
# Out:
# barrels08         0
# barrelsA08        0
# charge120         0
# charge240         0
# city08            0
#               ...
# modifiedOn        0
# startStop     31705
# phevCity          0
# phevHwy           0
# phevComb          0
# Length: 83, dtype: int64

# %%
type(df.isna().sum())
# Out:
# pandas.core.series.Series

# %%
missing_values = df.isna().sum()

# %%
missing_values.loc[missing_values.gt(0)]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
missing_values.loc[missing_values > 0]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
missing_values[missing_values.gt(0)]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
missing_values[missing_values.gt(0)]/len(df)
# Out:
# cylinders     0.003250
# displ         0.003171
# drive         0.031419
# eng_dscr      0.407024
# trany         0.000291
# guzzler       0.939725
# trans_dscr    0.602384
# tCharger      0.862960
# sCharger      0.982401
# atvType       0.918823
# fuelType2     0.962794
# rangeA        0.962926
# evMotor       0.985149
# mfrCode       0.814365
# c240Dscr      0.999022
# c240bDscr     0.999049
# startStop     0.837804
# dtype: float64

# %% [markdown]
# Drop all the columns that have more than 50% null values. We do not think this information will be useful in further analysis.

# %%
df.drop(columns=["c240bDscr", "c240Dscr"])
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  rangeA  evMotor  mfrCode  charge240b  \
# 0           0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 1           0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 2           0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 3           0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 4           0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# ...         ...     ...    ...  ...     ...      ...      ...         ...
# 37838       0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 37839       0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 37840       0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 37841       0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
# 37842       0.0     0.0    0.0  ...     NaN      NaN      NaN         0.0
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 37838  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 37839  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 37840  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 37841  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 37842  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# ...         ...      ...       ...
# 37838         0        0         0
# 37839         0        0         0
# 37840         0        0         0
# 37841         0        0         0
# 37842         0        0         0
#
# [37843 rows x 81 columns]

# %%
missing_values_ratios = missing_values[missing_values.gt(0)]/len(df)
missing_values_ratios
# Out:
# cylinders     0.003250
# displ         0.003171
# drive         0.031419
# eng_dscr      0.407024
# trany         0.000291
# guzzler       0.939725
# trans_dscr    0.602384
# tCharger      0.862960
# sCharger      0.982401
# atvType       0.918823
# fuelType2     0.962794
# rangeA        0.962926
# evMotor       0.985149
# mfrCode       0.814365
# c240Dscr      0.999022
# c240bDscr     0.999049
# startStop     0.837804
# dtype: float64

# %%
missing_values_ratios.loc[missing_values_ratios.gt(0.5)].index
# Out:
# Index(['guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
#        'rangeA', 'evMotor', 'mfrCode', 'c240Dscr', 'c240bDscr', 'startStop'],
#       dtype='object')

# %%
df_copy = df.drop(columns=missing_values_ratios.loc[missing_values_ratios.gt(0.5)].index).copy()

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# 0  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#    phevCity  phevHwy  phevComb
# 0         0        0         0
# 1         0        0         0
# 2         0        0         0
# 3         0        0         0
# 4         0        0         0
#
# [5 rows x 83 columns]

# %%
df_copy.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  UHighwayA           VClass  year  \
# 0       0.0     0.0    0.0  ...        0.0      Two Seaters  1985
# 1       0.0     0.0    0.0  ...        0.0      Two Seaters  1985
# 2       0.0     0.0    0.0  ...        0.0  Subcompact Cars  1985
# 3       0.0     0.0    0.0  ...        0.0             Vans  1985
# 4       0.0     0.0    0.0  ...        0.0     Compact Cars  1993
#
#    youSaveSpend  charge240b                     createdOn  \
# 0         -1250         0.0  Tue Jan 01 00:00:00 EST 2013
# 1         -8500         0.0  Tue Jan 01 00:00:00 EST 2013
# 2           500         0.0  Tue Jan 01 00:00:00 EST 2013
# 3         -8500         0.0  Tue Jan 01 00:00:00 EST 2013
# 4         -4000         0.0  Tue Jan 01 00:00:00 EST 2013
#
#                      modifiedOn  phevCity  phevHwy  phevComb
# 0  Tue Jan 01 00:00:00 EST 2013         0        0         0
# 1  Tue Jan 01 00:00:00 EST 2013         0        0         0
# 2  Tue Jan 01 00:00:00 EST 2013         0        0         0
# 3  Tue Jan 01 00:00:00 EST 2013         0        0         0
# 4  Tue Jan 01 00:00:00 EST 2013         0        0         0
#
# [5 rows x 71 columns]

# %%
#what about the columns that still have missing values, but aren't over 50%
(df_copy.isna().sum())[df_copy.isna().sum() > 0]
# Out:
# cylinders      123
# displ          120
# drive         1189
# eng_dscr     15403
# trany           11
# dtype: int64

# %%
# we have the ability to wrap this in a function
def cols_missing_value(df):
    return (df.isna().sum())[df.isna().sum() > 0]

# %%
cols_missing_value(df_copy)
# Out:
# cylinders      123
# displ          120
# drive         1189
# eng_dscr     15403
# trany           11
# dtype: int64

# %% [markdown]
# Investigate missing values in the `cylinders` column

# %%
relevant_columns = ["year", "make", "trany", "drive", "fuelType", "cylinders", "displ"]
df_copy.loc[df_copy["cylinders"].isna(), relevant_columns].head(30)
# Out:
#        year        make           trany              drive     fuelType  \
# 7138   2000      Nissan             NaN                NaN  Electricity
# 7139   2000      Toyota             NaN      2-Wheel Drive  Electricity
# 8143   2001      Toyota             NaN      2-Wheel Drive  Electricity
# 8144   2001        Ford             NaN                NaN  Electricity
# 8146   2001        Ford             NaN      2-Wheel Drive  Electricity
# 8147   2001      Nissan             NaN                NaN  Electricity
# 9212   2002      Toyota             NaN      2-Wheel Drive  Electricity
# 9213   2002        Ford             NaN      2-Wheel Drive  Electricity
# 10329  2003      Toyota             NaN      2-Wheel Drive  Electricity
# 21413  1985      Subaru    Manual 5-spd      4-Wheel Drive      Regular
# 21414  1985      Subaru    Manual 5-spd      4-Wheel Drive      Regular
# 21506  1986       Mazda    Manual 5-spd   Rear-Wheel Drive      Regular
# 23026  2001        Ford  Automatic (A1)      2-Wheel Drive  Electricity
# 23027  2000        Ford  Automatic (A1)      2-Wheel Drive  Electricity
# 23028  2000        Ford  Automatic (A1)      2-Wheel Drive  Electricity
# 23029  1999         GMC  Automatic (A1)                NaN  Electricity
# 23030  1999         GMC  Automatic (A1)                NaN  Electricity
# 23032  1999       Honda  Automatic (A1)                NaN  Electricity
# 23033  1999        Ford  Automatic (A1)      2-Wheel Drive  Electricity
# 23034  1999        Ford  Automatic (A1)      2-Wheel Drive  Electricity
# 23035  1999       Dodge  Automatic (A1)      2-Wheel Drive  Electricity
# 23036  1999    Plymouth  Automatic (A1)  Front-Wheel Drive  Electricity
# 23037  1998       Honda  Automatic (A1)                NaN  Electricity
# 23038  1998   Chevrolet  Automatic (A1)      2-Wheel Drive  Electricity
# 23039  1998   Chevrolet  Automatic (A1)      2-Wheel Drive  Electricity
# 23040  2008        MINI  Automatic (A1)                NaN  Electricity
# 23041  2011      Nissan  Automatic (A1)  Front-Wheel Drive  Electricity
# 23137  2011       smart  Automatic (A1)   Rear-Wheel Drive  Electricity
# 23138  2011       smart  Automatic (A1)   Rear-Wheel Drive  Electricity
# 23807  2012  Mitsubishi  Automatic (A1)   Rear-Wheel Drive  Electricity
#
#        cylinders  displ
# 7138         NaN    NaN
# 7139         NaN    NaN
# 8143         NaN    NaN
# 8144         NaN    NaN
# 8146         NaN    NaN
# 8147         NaN    NaN
# 9212         NaN    NaN
# 9213         NaN    NaN
# 10329        NaN    NaN
# 21413        NaN    NaN
# 21414        NaN    NaN
# 21506        NaN    1.3
# 23026        NaN    NaN
# 23027        NaN    NaN
# 23028        NaN    NaN
# 23029        NaN    NaN
# 23030        NaN    NaN
# 23032        NaN    NaN
# 23033        NaN    NaN
# 23034        NaN    NaN
# 23035        NaN    NaN
# 23036        NaN    NaN
# 23037        NaN    NaN
# 23038        NaN    NaN
# 23039        NaN    NaN
# 23040        NaN    NaN
# 23041        NaN    NaN
# 23137        NaN    NaN
# 23138        NaN    NaN
# 23807        NaN    NaN

# %%
df_copy.loc[df_copy["cylinders"].isna(), "fuelType"].value_counts()
# Out:
# Electricity    120
# Regular          3
# Name: fuelType, dtype: int64

# %%
#where cylinders is NA and where is fuelType Electricity
df_copy.loc[(df_copy["cylinders"].isna()) & (df_copy["fuelType"] == "Electricity"), "cylinders"] = 0

# %%
df_copy.loc[df_copy["cylinders"].isna(), "fuelType"].value_counts()
# Out:
# Regular    3
# Name: fuelType, dtype: int64

# %%
df_copy.loc[df_copy["cylinders"].isna(), relevant_columns]
# Out:
#        year    make         trany             drive fuelType  cylinders  displ
# 21413  1985  Subaru  Manual 5-spd     4-Wheel Drive  Regular        NaN    NaN
# 21414  1985  Subaru  Manual 5-spd     4-Wheel Drive  Regular        NaN    NaN
# 21506  1986   Mazda  Manual 5-spd  Rear-Wheel Drive  Regular        NaN    1.3

# %% [markdown]
# Fill the remaining NAs in `cylinders` with 0

# %%
df_copy["cylinders"] = df_copy["cylinders"].fillna(0)

# %% [markdown]
# ## 2. Look at information contained in a column (Cardinality/Variance)

# %% [markdown]
# #### Example, What if we had one column with only 1 value

# %%
df_copy.assign(vehicle=True)["vehicle"].value_counts()
# Out:
# True    37843
# Name: vehicle, dtype: int64

# %%
len(df_copy.assign(vehicle=True)["vehicle"].value_counts())
# Out:
# 1

# %% [markdown]
# This columns would not give us any useful information as it only has 1 unique value.

# %% [markdown]
# Look at other numerical columns:

# %%
df_copy[["barrels08"]].sort_values("barrels08")
# Out:
#        barrels08
# 25835   0.060000
# 24539   0.060000
# 27174   0.060000
# 28455   0.060000
# 14370   0.066429
# ...          ...
# 31336  47.087143
# 7901   47.087143
# 21060  47.087143
# 33860  47.087143
# 32586  47.087143
#
# [37843 rows x 1 columns]

# %%
df_copy[["barrels08"]].describe()
# Out:
#           barrels08
# count  37843.000000
# mean      17.532506
# std        4.575950
# min        0.060000
# 25%       14.330870
# 50%       17.347895
# 75%       20.600625
# max       47.087143

# %% [markdown]
# If 90% of the rows in the column have the same value, we might as well drop it.
# - 1. for a given column, identify the minimum value
# - 2. for the same column, identify the 90% percentile
# - 3. if min == 90th per, drop the column

# %%
#1 
min_b = df_copy["barrels08"].min()

#2
n_perc = np.percentile(df_copy["barrels08"], 90)

#3
min_b == n_perc
# Out:
# False
