# %%
import json;
import requests
from pandas.io.json import json_normalize

# %% [markdown]
# # Challenge 1

# %% [markdown]
# ## 1. Obtain the full list of forks created from the main lab repo via Github API.

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/forks', auth=(user_name, token));
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1780bc142b01> in <module>
# ----> 1 response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/forks', auth=(user_name, token));
#       2 data = response.json()
#
# NameError: name 'user_name' is not defined

# %%
data

# %%
# Normalize semi-structured JSON data into a flat table. 
forks = json_normalize(data);
forks.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7b80aa4dfeb5> in <module>
#       1 # Normalize semi-structured JSON data into a flat table.
# ----> 2 forks = json_normalize(data);
#       3 forks.head(10)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.

# %%
languages = [];

for language in forks['language']:
    if language not in languages:
        languages.append(language); 
        
print(languages)
# Out:
# ['Jupyter Notebook']

# %%
# Alternative
languages = list(forks.language.unique())
print(languages);
# Out:
# ['Jupyter Notebook']

# %% [markdown]
# # Challenge 2: Count Commits

# %% [markdown]
# ## 1. Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/commits', auth=('TheManohar', '9232ab66b9c233b2589a87c7c28822699ab70482'))

# %%
#response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/commits?since=2019-15-01T00:00:00Z', auth=('TheManohar', '9232ab66b9c233b2589a87c7c28822699ab70482'))

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json();
commits = json_normalize(data)
commits['commit.author.date']
# Out:
# 0     2019-06-17T13:33:10Z
# 1     2019-06-17T13:32:17Z
# 2     2019-05-22T21:32:46Z
# 3     2019-05-21T21:02:16Z
# 4     2019-05-20T19:46:31Z
# 5     2019-05-17T16:36:02Z
# 6     2019-05-17T15:39:01Z
# 7     2019-05-17T14:04:59Z
# 8     2019-05-15T13:53:32Z
# 9     2019-05-15T13:51:11Z
# 10    2019-05-14T20:35:21Z
# 11    2019-05-10T22:09:41Z
# 12    2019-05-10T21:52:36Z
# 13    2019-05-07T21:07:49Z
# 14    2019-05-07T20:45:15Z
# 15    2019-04-18T19:40:40Z
# 16    2019-03-15T12:00:39Z
# 17    2019-03-09T04:10:24Z
# 18    2019-03-08T18:16:28Z
# 19    2019-03-05T04:35:09Z
# 20    2019-03-03T18:01:15Z
# 21    2019-02-22T18:56:01Z
# 22    2019-02-22T18:51:01Z
# 23    2019-02-21T03:40:38Z
# 24    2019-02-20T20:52:42Z
# 25    2019-02-20T20:50:19Z
# 26    2019-02-20T16:29:54Z
# 27    2019-02-19T19:58:37Z
# 28    2019-02-19T19:57:36Z
# 29    2019-02-19T19:01:23Z
# Name: commit.author.date, dtype: object

# %% [markdown]
# ## 2. Count how many commit objects are contained in the array.

# %%
len(commits)
# Out:
# 30

# %% [markdown]
# # Challenge 3: Hidden Cold Joke

# %%
#response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger', auth=('TheManohar', '9232ab66b9c233b2589a87c7c28822699ab70482'));
#search = response.json()

print(search)
# Out:
# {'total_count': 24, 'incomplete_results': False, 'items': [{'name': '.0006.scavengerhunt', 'path': '15024/.0006.scavengerhunt', 'sha': '1c9064284a24b3486015eafdb391b141c27ada2b', 'url': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://githu
# ...

# %%
#flat = json_normalize(search)
#flat

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger');
search = response.json()

print(search)
# Out:
# {'total_count': 24, 'incomplete_results': False, 'items': [{'name': '.0006.scavengerhunt', 'path': '15024/.0006.scavengerhunt', 'sha': '1c9064284a24b3486015eafdb391b141c27ada2b', 'url': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://githu
# ...

# %%
files = flat['items'];
files = sorted(files, key=lambda file: file['name']);

print(files)
# Out:
# -----------------------------------------------------------
# TypeError                 Traceback (most recent call last)
# <ipython-input-82-e6007cefbb6f> in <module>
#       1 files = flat['items'];
# ----> 2 files = sorted(files, key=lambda file: file['name']);
#       3
#       4 print(files)
#
# <ipython-input-82-e6007cefbb6f> in <lambda>(file)
#       1 files = flat['items'];
# ----> 2 files = sorted(files, key=lambda file: file['name']);
#       3
#       4 print(files)
#
# TypeError: list indices must be integers or slices, not str

# %%
contents_list = []
headers = {'Accept': 'application/vnd.github.v3.raw', };

# %%
for file in files:
    content_path = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}'.format(file['path']);
    response = requests.get(content_path, headers=headers);
    contents_list.append(response.text);

# %%
print(contents_list)
# Out:
# ['In\n', 'data\n', 'science,\n', '80\n', 'percent\n', 'of\n', 'time\n', 'spent\n', 'is\n', 'preparing\n', 'data,\n', '20\n', 'percent\n', 'of\n', 'time\n', 'is\n', 'spent\n', 'complaining\n', 'about\n', 'the\n', 'need\n', 'to\n', 'prepare\n', 'data.\n']

# %%
clean_contents = [word.strip('\n') for word in contents_list]
joke = " ".join(clean_contents);

# %%
print(joke)
# Out:
# In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.
